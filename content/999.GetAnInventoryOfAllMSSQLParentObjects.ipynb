# %% [markdown]
# # Get an Inventory of all MSSQL Parent Objects

# %% [markdown]
# In Rubrik, MSSQL Objects have a parent child relationship. The database is always the child, while the SQL Server Instance or the Availability Group is the parent.
#
# When databases first get put onto an Instance, the Instance is the parent of the child. When a DBA decides that a database should be inside an Availability Group, then the Availability Group becomes the parent. This is important information to know and understand. In Rubrik, the parent is also known as the **location** of the database.
#
# Think about a situation where you want to search Rubrik for a database name called AdventureWorks. Simply searching for the database name could return back multiple entries as the database could exist on multiple locations. To narrow down the number of returned records, you want to include a location. Either the Availability Group, or the SQL Server Instance. This ensure that you get back the correct occurance of the AdventureWorks database.

# %% [markdown]
# ## Connect to Rubrik Security Cloud

# %%
Import-Module RubrikSecurityCloud
Connect-Rsc
# Out:
# WARNING: Connect_Rsc: The installed RSC SDK version does not match the server version.
#
# ClientId                                AuthenticationState SdkSchemaVersion ServerVersion
# --------                                ------------------- ---------------- -------------
# client|kB5og68XXrFlfXcvWhn3jlHdf1OKyJCB          AUTHORIZED v20230802-35     v20230802-41

# %% [markdown]
# ## List all Parent Objects
# For SQL Server objects, Rubrik works with a parent/child relationship. The database is always the child, but the parent can be different depending upon configuration. In the majority of use cases, the parent of a database is the SQL Server Instance. Databases in an Availability Group configuration, the parent is the Availability Group, not the SQL Server Instance. Even though the database may phsyically reside upon 2 or more instances of SQL Server, the parent is the AG. This is because, you can assign seperate SLA Domain to each replica server. In this case, Rubrik would have a difficult time performing conflict resolution if database in the AG could 2 or more SLA Domain rules goverening it depending upon backup preferences. To simplify this and not have conflicts, Rubrik makes the AG the parent of the database. Then, regardless of which replica server the backup was taken on, the same SLA manages the life cycle of the backup.

# %%
$RSCMSSQLInventory = (Invoke-RscQueryMssql -TopLevelDescendant).Nodes
$RSCMSSQLInventory
# Out:
# AuthorizedOperations        :
# ObjectType                  : WINDOWS_CLUSTER
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# Id                          : 09610691-4cfb-541a-923e-4c0ade1b86c3
# Name                        : RP-SQL19AGD-1
# NumWorkloadDescendants      : 0
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Hosts                       :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   :
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : 0feeedc3-047d-54e1-8d16-0ce93d0ff828
# IpAddresses                 :
# IsArchived                  : True
# IsChangelistEnabled         : False
# IsOracleHost                : False
# Name                        : rp-sql-test-01.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 0
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : 1176c065-3434-5c87-b69f-597560c8cb17
# IpAddresses                 :
# IsArchived                  : False
# IsChangelistEnabled         : False
# IsOracleHost                : True
# Name                        : rp-sql19ags-1a.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 10
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   :
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : 133ef792-5938-566b-aab2-6ccf9d261492
# IpAddresses                 :
# IsArchived                  : False
# IsChangelistEnabled         : False
# IsOracleHost                : False
# Name                        : rp-sql22ags-1a.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 32
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : 14057524-77ef-5d82-b6b2-c2981ec65d9b
# IpAddresses                 :
# IsArchived                  : False
# IsChangelistEnabled         : False
# IsOracleHost                : True
# Name                        : rp-sql19agd-1a.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 8
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : 1853648d-9b0c-5afc-8c91-80cd8d0d561a
# IpAddresses                 :
# IsArchived                  : True
# IsChangelistEnabled         : False
# IsOracleHost                : False
# Name                        : rp-ndu-sql01.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 0
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : MSSQL_AVAILABILITY_GROUP
# SlaAssignment               : DIRECT
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# CopyOnly                    :
# HasLogConfigFromSla         : True
# Id                          : 19630be1-7a3c-5ec8-ad18-62852bc82cba
# LogBackupFrequencyInSeconds :
# LogBackupRetentionInHours   :
# Name                        : RR-SQL22-AG2
# NumWorkloadDescendants      : 2
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Instances                   :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : MSSQL_AVAILABILITY_GROUP
# SlaAssignment               : DIRECT
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# CopyOnly                    :
# HasLogConfigFromSla         : True
# Id                          : 23c03795-36f7-5812-a18e-5a3a5cbb714c
# LogBackupFrequencyInSeconds :
# LogBackupRetentionInHours   :
# Name                        : DC1-AG1
# NumWorkloadDescendants      : 1
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Instances                   :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : 23fdb155-57bb-5cbb-9ec6-847bad6f09aa
# IpAddresses                 :
# IsArchived                  : False
# IsChangelistEnabled         : False
# IsOracleHost                : False
# Name                        : rp-sql19ags-1c.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 9
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : 25921799-0ec0-5498-87d8-a80ca8e32003
# IpAddresses                 :
# IsArchived                  : False
# IsChangelistEnabled         : False
# IsOracleHost                : False
# Name                        : rp-sql17s-001.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 7
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : MSSQL_AVAILABILITY_GROUP
# SlaAssignment               : DIRECT
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# CopyOnly                    :
# HasLogConfigFromSla         : True
# Id                          : 28e4aa44-386e-55dd-8a52-a1882e3c1f4e
# LogBackupFrequencyInSeconds :
# LogBackupRetentionInHours   :
# Name                        : RR-SQL22-AG5
# NumWorkloadDescendants      : 3
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Instances                   :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : 2ccf7309-9cc3-500d-8dc5-2190683ba36a
# IpAddresses                 :
# IsArchived                  : True
# IsChangelistEnabled         : False
# IsOracleHost                : True
# Name                        : rp-sql19agd-1b.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 1
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : 32dc1877-dcc8-583c-a942-589702fe4a6c
# IpAddresses                 :
# IsArchived                  : False
# IsChangelistEnabled         : False
# IsOracleHost                : False
# Name                        : rp-sql12s-001.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 9
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : MSSQL_AVAILABILITY_GROUP
# SlaAssignment               : DIRECT
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# CopyOnly                    :
# HasLogConfigFromSla         : True
# Id                          : 37d606ef-0e98-5e15-bb93-b50497484694
# LogBackupFrequencyInSeconds :
# LogBackupRetentionInHours   :
# Name                        : rp-sql19ags-g1
# NumWorkloadDescendants      : 4
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Instances                   :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   :
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : 38c3d748-9b95-5a42-a180-a9050b60b3f5
# IpAddresses                 :
# IsArchived                  : True
# IsChangelistEnabled         : False
# IsOracleHost                : False
# Name                        : 10.51.12.91
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 0
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : WINDOWS_CLUSTER
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# Id                          : 3a41fc08-d31a-5a22-8fda-e59bba0497ec
# Name                        : FC3
# NumWorkloadDescendants      : 0
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Hosts                       :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   :
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : 3c20bcb6-7d84-52e7-bd85-dacaca6fa721
# IpAddresses                 :
# IsArchived                  : True
# IsChangelistEnabled         : False
# IsOracleHost                : True
# Name                        : rp-sql14s-001.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 0
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : MSSQL_AVAILABILITY_GROUP
# SlaAssignment               : DIRECT
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# CopyOnly                    :
# HasLogConfigFromSla         : True
# Id                          : 4ae4dd07-9949-5754-846f-d8137b4a066c
# LogBackupFrequencyInSeconds :
# LogBackupRetentionInHours   :
# Name                        : RR-SQL22-AG4
# NumWorkloadDescendants      : 3
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Instances                   :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : 4c36e3f6-0253-5306-a909-0614407c37e0
# IpAddresses                 :
# IsArchived                  : False
# IsChangelistEnabled         : False
# IsOracleHost                : True
# Name                        : rp-sql14s-001.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 7
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : MSSQL_AVAILABILITY_GROUP
# SlaAssignment               : DIRECT
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# CopyOnly                    :
# HasLogConfigFromSla         : True
# Id                          : 4c7de17f-51c8-5dc5-aff6-d2c4bb43e597
# LogBackupFrequencyInSeconds :
# LogBackupRetentionInHours   :
# Name                        : RR-SQL22-AG7
# NumWorkloadDescendants      : 3
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Instances                   :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : MSSQL_AVAILABILITY_GROUP
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# CopyOnly                    :
# HasLogConfigFromSla         : False
# Id                          : 53eb7226-f045-5025-8007-be30047b4a51
# LogBackupFrequencyInSeconds :
# LogBackupRetentionInHours   :
# Name                        : rp-sql19ags-g3
# NumWorkloadDescendants      : 1
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Instances                   :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : MSSQL_AVAILABILITY_GROUP
# SlaAssignment               : DIRECT
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# CopyOnly                    :
# HasLogConfigFromSla         : True
# Id                          : 57e4e24d-8a1c-57f2-abcc-bc062d8b055c
# LogBackupFrequencyInSeconds :
# LogBackupRetentionInHours   :
# Name                        : RR-SQL22-AG3
# NumWorkloadDescendants      : 3
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Instances                   :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : WINDOWS_CLUSTER
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# Id                          : 5ec07ee6-c85f-5afe-ad63-d102e82753eb
# Name                        : rp-hyperv-c1
# NumWorkloadDescendants      : 0
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Hosts                       :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : WINDOWS_CLUSTER
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# Id                          : 67486726-1ce6-574e-bc30-e71757f5a41b
# Name                        : RP-SQL19AGD-2
# NumWorkloadDescendants      : 0
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Hosts                       :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : 6e02668f-2d63-5a2d-90bf-204df7676728
# IpAddresses                 :
# IsArchived                  : False
# IsChangelistEnabled         : False
# IsOracleHost                : True
# Name                        : rp-sql19ags-1b.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 11
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : 71429fe3-912a-54d1-9442-6833a17a033c
# IpAddresses                 :
# IsArchived                  : False
# IsChangelistEnabled         : False
# IsOracleHost                : False
# Name                        : rp-jump-sql.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 5
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : MSSQL_AVAILABILITY_GROUP
# SlaAssignment               : DIRECT
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# CopyOnly                    :
# HasLogConfigFromSla         : True
# Id                          : 7332f61f-2a05-5d0e-b3d2-552259d593d7
# LogBackupFrequencyInSeconds :
# LogBackupRetentionInHours   :
# Name                        : RR-SQL22-AG9
# NumWorkloadDescendants      : 3
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Instances                   :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : MSSQL_AVAILABILITY_GROUP
# SlaAssignment               : DIRECT
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# CopyOnly                    :
# HasLogConfigFromSla         : True
# Id                          : 74e83899-2a05-558d-99da-69f9e6e9a226
# LogBackupFrequencyInSeconds :
# LogBackupRetentionInHours   :
# Name                        : RR-SQL22-AG8
# NumWorkloadDescendants      : 3
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Instances                   :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : 76f6cc82-b004-55a8-8d2f-411113e4831f
# IpAddresses                 :
# IsArchived                  : False
# IsChangelistEnabled         : False
# IsOracleHost                : False
# Name                        : rp-sql19agd-1d.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 1
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : 971a6c99-6812-5168-b696-ee7bae9f3455
# IpAddresses                 :
# IsArchived                  : True
# IsChangelistEnabled         : False
# IsOracleHost                : True
# Name                        : rp-sql19agd-1c.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 0
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : 9a2bc8af-3e59-5036-bfc4-a6252fd968e9
# IpAddresses                 :
# IsArchived                  : False
# IsChangelistEnabled         : False
# IsOracleHost                : False
# Name                        : rp-sql19s-001.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 7
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : 9b1a9da5-c7ee-5073-804f-15c854f73473
# IpAddresses                 :
# IsArchived                  : False
# IsChangelistEnabled         : False
# IsOracleHost                : False
# Name                        : rp-sql19sl-02.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 6
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : MSSQL_AVAILABILITY_GROUP
# SlaAssignment               : DIRECT
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# CopyOnly                    :
# HasLogConfigFromSla         : True
# Id                          : 9ed800de-af9a-588f-a0bd-1da47562faef
# LogBackupFrequencyInSeconds :
# LogBackupRetentionInHours   :
# Name                        : rp-sql19ags-g2
# NumWorkloadDescendants      : 1
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Instances                   :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : afdbedf7-d780-5707-b6bd-25ab75b6f730
# IpAddresses                 :
# IsArchived                  : True
# IsChangelistEnabled         : False
# IsOracleHost                : False
# Name                        : rp-sql19sl-02.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 0
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : MSSQL_AVAILABILITY_GROUP
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# CopyOnly                    :
# HasLogConfigFromSla         : False
# Id                          : baee9e0d-9764-57dc-bd58-df0185dffa04
# LogBackupFrequencyInSeconds :
# LogBackupRetentionInHours   :
# Name                        : DC2-AG1
# NumWorkloadDescendants      : 0
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Instances                   :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : bfb1ca21-a90c-5d11-a8a8-fc047dde691d
# IpAddresses                 :
# IsArchived                  : True
# IsChangelistEnabled         : False
# IsOracleHost                : True
# Name                        : rp-sql19sd-01.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 0
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   :
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : c5e2d075-5a91-57d7-8ce9-93792f1d9c7f
# IpAddresses                 :
# IsArchived                  : True
# IsChangelistEnabled         : False
# IsOracleHost                : False
# Name                        : rp-sql12s-001.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 0
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : d2f7bd73-0b1b-5912-8c7d-bac1c46d6217
# IpAddresses                 :
# IsArchived                  : False
# IsChangelistEnabled         : False
# IsOracleHost                : True
# Name                        : rp-sql19sl-01.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 13
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : d2f9acd7-291b-5011-8772-886ba33b7b16
# IpAddresses                 :
# IsArchived                  : False
# IsChangelistEnabled         : False
# IsOracleHost                : False
# Name                        : rp-sqldev-01.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 21
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : dd7e7bd6-d5a0-53d0-a873-fc73e92faaed
# IpAddresses                 :
# IsArchived                  : False
# IsChangelistEnabled         : False
# IsOracleHost                : False
# Name                        : rp-sql19sd-02.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 604
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   :
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : e41cd8fa-fb64-5b59-900b-bebb9d627f5d
# IpAddresses                 :
# IsArchived                  : False
# IsChangelistEnabled         : False
# IsOracleHost                : False
# Name                        : rp-sql22ags-1b.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 29
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : MSSQL_AVAILABILITY_GROUP
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# CopyOnly                    :
# HasLogConfigFromSla         : False
# Id                          : e6798d9c-87ed-55f9-a268-6af3e609ddc4
# LogBackupFrequencyInSeconds :
# LogBackupRetentionInHours   :
# Name                        : test
# NumWorkloadDescendants      : 3
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Instances                   :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : WINDOWS_CLUSTER
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# Id                          : e818bbdc-cb6f-5f81-93be-288519f1e8a7
# Name                        : RP-SQL19AGS-1
# NumWorkloadDescendants      : 0
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Hosts                       :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : e866375e-8dde-50a6-b97e-77d274dfe0e3
# IpAddresses                 :
# IsArchived                  : False
# IsChangelistEnabled         : False
# IsOracleHost                : True
# Name                        : rp-sql19wmv-1.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 7
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : MSSQL_AVAILABILITY_GROUP
# SlaAssignment               : DIRECT
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# CopyOnly                    :
# HasLogConfigFromSla         : True
# Id                          : edb41b7f-3b1b-5a18-8ee3-5027a0c343df
# LogBackupFrequencyInSeconds :
# LogBackupRetentionInHours   :
# Name                        : RR-SQL22-AG6
# NumWorkloadDescendants      : 3
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Instances                   :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : MSSQL_AVAILABILITY_GROUP
# SlaAssignment               : DIRECT
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# CopyOnly                    :
# HasLogConfigFromSla         : True
# Id                          : ee24ebfc-34c0-5da1-a1f7-912839cacab5
# LogBackupFrequencyInSeconds :
# LogBackupRetentionInHours   :
# Name                        : RR-SQL22-AG1
# NumWorkloadDescendants      : 1
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Instances                   :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : WINDOWS_CLUSTER
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# Id                          : f0ef35c5-8140-5f48-a63d-d16aab23da05
# Name                        : RP-SQL22AGS-1
# NumWorkloadDescendants      : 0
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Hosts                       :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : f35c9c4b-ca9d-5d65-bb4a-b4d4a1ab72f3
# IpAddresses                 :
# IsArchived                  : False
# IsChangelistEnabled         : False
# IsOracleHost                : True
# Name                        : rp-sql16s-001.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 11
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   :
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : fa2067f5-3ad6-5994-b488-347f8d316fe9
# IpAddresses                 :
# IsArchived                  : True
# IsChangelistEnabled         : False
# IsOracleHost                : False
# Name                        : lurie-bigvm-01.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 0
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : MSSQL_AVAILABILITY_GROUP
# SlaAssignment               : DIRECT
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# CopyOnly                    :
# HasLogConfigFromSla         : True
# Id                          : fad524ea-3aba-59a2-abcf-b4a0e4713e25
# LogBackupFrequencyInSeconds :
# LogBackupRetentionInHours   :
# Name                        : AG_tpcc
# NumWorkloadDescendants      : 1
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Instances                   :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :

# %% [markdown]
# The data returned back is a simple list of Windows Clusters, Phsyical Hosts and Availability Groups. Additionally, when working with the SQL Server Instance, most instances are the defualt instance of MSSQLSERVER, but in some environments, they may have named instances. Like machine.domain.com\sql01 or machine.domain.com\sqlweb. From here we need to start to filter out records we do not want.

# %% [markdown]
# ## Get an Instance of SQL Server
# ### Using Filter Object
# Because we are using GraqhQL, we have the ability to send an object that contains the fields we want to filter on. In the example below, we are creating a hashtable called `$filter` which contains our filter predicates.

# %%
$filter = @(
    @{
        "field" = "NAME"
        "texts" = "rp-sql19sl-01.perf.rubrik.com"
    }
)
$inputs = Invoke-RscQueryMssql -TopLevelDescendant -GetInputs
$inputs.Arg.filter = $Filter
$RSCMSSQLInventory = Invoke-RscQueryMssql -TopLevelDescendant -Arg $inputs.Arg
$RSCMSSQLInventory.Nodes
$RSCMSSQLInventory.Nodes.PhysicalChildConnection.Nodes
# Out:
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : d2f7bd73-0b1b-5912-8c7d-bac1c46d6217
# IpAddresses                 :
# IsArchived                  : False
# IsChangelistEnabled         : False
# IsOracleHost                : True
# Name                        : rp-sql19sl-01.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 13
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : MSSQL_INSTANCE
# SlaAssignment               : DIRECT
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# HasLogConfigFromSla         : True
# Id                          : 7e785f59-5848-532c-8397-9c64b7a9c319
# LogBackupFrequencyInSeconds :
# LogBackupRetentionInHours   :
# Name                        : MSSQLSERVER
# NumWorkloadDescendants      : 12
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# UnprotectableReasons        :
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations            :
# ObjectType                      : VOLUME_GROUP
# SlaAssignment                   : UNASSIGNED
# ConfiguredSlaDomain             :
# EffectiveRetentionSlaDomain     :
# EffectiveSlaDomain              : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                      :
# ReplicatedObjects               :
# CdmId                           :
# CdmLink                         :
# Id                              : fafa2b5b-aa3f-5266-ad88-8967f53ac660
# IsRelic                         : False
# Name                            : rp-sql19sl-01.perf.rubrik.com volumes
# NumWorkloadDescendants          : 0
# OnDemandSnapshotCount           :
# ReplicatedObjectCount           :
# SlaPauseStatus                  : False
# Volumes                         :
# AllOrgs                         :
# CdmSnapshots                    :
# Cluster                         :
# EffectiveSlaSourceObject        :
# LatestUserNote                  :
# LogicalPath                     :
# MissedSnapshotConnection        :
# MissedSnapshotGroupByConnection :
# NewestArchivedSnapshot          :
# NewestReplicatedSnapshot        :
# NewestSnapshot                  :
# OldestSnapshot                  :
# PendingObjectDeletionStatus     :
# PhysicalPath                    :
# PrimaryClusterLocation          :
# SnapshotConnection              :
# SnapshotDistribution            :
# SnapshotGroupByConnection       :
# SnapshotGroupBySummary          :

# %% [markdown]
# ### Using Powershell Where-Object
# This approach is more familiar and traditional to Powershell users. In this example, we are still filtering on host to get an SQL Server Instance. We are also adding an additional filter for the name of the SQL Server Instance.

# %%
$SQLServerHost = "rp-sql19sl-01.perf.rubrik.com"
$RSCMSSQLInventory = (Invoke-RscQueryMssql -TopLevelDescendant).Nodes | Where-Object {$_.Name -eq $SQLServerHost}
$RSCMSSQLInventory
$RSCMSSQLInventory.PhysicalChildConnection.Nodes | Where-Object {$_.ObjectType -eq "MSSQL_INSTANCE" -and $_.Name -eq "MSSQLSERVER"}
# Out:
# AuthorizedOperations        :
# ObjectType                  : PHYSICAL_HOST
# OsType                      :
# SlaAssignment               : UNASSIGNED
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# AgentId                     :
# CbtStatus                   : Enabled
# CdmId                       :
# CdmLink                     :
# DefaultCbt                  :
# Id                          : d2f7bd73-0b1b-5912-8c7d-bac1c46d6217
# IpAddresses                 :
# IsArchived                  : False
# IsChangelistEnabled         : False
# IsOracleHost                : True
# Name                        : rp-sql19sl-01.perf.rubrik.com
# NasMigrationInfo            :
# NasVendorType               :
# NumWorkloadDescendants      : 13
# OsName                      :
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# VfdState                    : NotInstalled
# AllOrgs                     :
# Cluster                     :
# ConnectionStatus            :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# HostVolumes                 :
# LatestUserNote              :
# LogicalPath                 :
# OracleUserDetails           :
# PendingObjectDeletionStatus :
# PhysicalChildConnection     : RubrikSecurityCloud.Types.PhysicalHostPhysicalChildTypeConnection
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : MSSQL_INSTANCE
# SlaAssignment               : DIRECT
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# HasLogConfigFromSla         : True
# Id                          : 7e785f59-5848-532c-8397-9c64b7a9c319
# LogBackupFrequencyInSeconds :
# LogBackupRetentionInHours   :
# Name                        : MSSQLSERVER
# NumWorkloadDescendants      : 12
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# UnprotectableReasons        :
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :

# %% [markdown]
# With the above information, we get back some information. The important information is the **id** and **name** fields. These fields are used later to get databases or perform operations like Live Mount, Export, Restore, or take a backup. The data returned has a couple of different IDs. The id attached to the object type of PHYSICAL_HOST is not the ID you will need later for working SQL Server objects or operations. You will need the id found in the PhysicalChildConnection section and filter on object type of MSSQL_INSTANCE. If you are dealing with named instances, then you will want to add an additional predicate of name being equal to the name of the instance as shown in the exmaple above.

# %% [markdown]
# ## Get an Availability Group

# %%
$filter = @(
    @{
        "field" = "NAME"
        "texts" = "RR-SQL22-AG1"
    },
    @{
        "field" = "IS_ARCHIVED"
        "texts" = "false"
    },
    @{
        "field" = "IS_RELIC"
        "texts" = "false"
    },
    @{
        "field" = "IS_GHOST"
        "texts" = "false"
    }
    
)
$inputs = Invoke-RscQueryMssql -TopLevelDescendant -GetInputs
$inputs.Arg.filter = $Filter
$RSCMSSQLInventory = Invoke-RscQueryMssql -TopLevelDescendant -Arg $inputs.Arg
$RSCMSSQLInventory.Nodes
# $RSCMSSQLInventory.Nodes.PhysicalChildConnection.Nodes 

# $AGName = "RR-SQL22-AG1"
# $RSCMSSQLInventory = (Invoke-RscQueryMssql -TopLevelDescendant).Nodes | Where-Object {$_.ObjectType -eq "MSSQL_AVAILABILITY_GROUP" -and $_.Name -eq $AGName}
# $RSCMSSQLInventory
# Out:
# AuthorizedOperations        :
# ObjectType                  : MSSQL_AVAILABILITY_GROUP
# SlaAssignment               : DIRECT
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# CopyOnly                    :
# HasLogConfigFromSla         : True
# HostLogRetention            :
# Id                          : daae59eb-66d8-58b2-b8ca-e525a7b47aa8
# LogBackupFrequencyInSeconds :
# LogBackupRetentionInHours   :
# Name                        : RR-SQL22-AG1
# NumWorkloadDescendants      : 1
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Instances                   :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :
#
# AuthorizedOperations        :
# ObjectType                  : MSSQL_AVAILABILITY_GROUP
# SlaAssignment               : DIRECT
# ConfiguredSlaDomain         :
# EffectiveRetentionSlaDomain :
# EffectiveSlaDomain          : RubrikSecurityCloud.Types.GlobalSlaReply
# PendingSla                  :
# ReplicatedObjects           :
# CopyOnly                    :
# HasLogConfigFromSla         : True
# HostLogRetention            :
# Id                          : ee24ebfc-34c0-5da1-a1f7-912839cacab5
# LogBackupFrequencyInSeconds :
# LogBackupRetentionInHours   :
# Name                        : RR-SQL22-AG1
# NumWorkloadDescendants      : 1
# ReplicatedObjectCount       :
# SlaPauseStatus              : False
# AllOrgs                     :
# Cluster                     :
# DescendantConnection        :
# EffectiveSlaSourceObject    :
# Instances                   :
# LatestUserNote              :
# LogicalChildConnection      :
# LogicalPath                 :
# PendingObjectDeletionStatus :
# PhysicalPath                :
# PrimaryClusterLocation      :
# SnapshotDistribution        :

# %% [markdown]
# In this example, we get back the **id** and **name** of the Availability Group. This will be information we will need going forward to work with SQL Server objects or do operational tasks.
